# %%
from __future__ import print_function

from sklearn import datasets
from sklearn.cross_validation import train_test_split
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC

print(__doc__)

# Loading the Digits dataset
digits = datasets.load_digits()


n_samples = len(digits.data)
X = digits.data
y = digits.target

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=0)

# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(SVC(C=1), tuned_parameters, cv=5, scoring=score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_estimator_)
    print()
    print("Grid scores on development set:")
    print()
    for params, mean_score, scores in clf.grid_scores_:
        print("%0.3f (+/-%0.03f) for %r"
              % (mean_score, scores.std() / 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# Automatically created module for IPython interactive environment
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.001,
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)
#
# Grid scores on development set:
#
# 0.987 (+/-0.005) for {'gamma': 0.001, 'kernel': 'rbf', 'C': 1}
# 0.959 (+/-0.007) for {'gamma': 0.0001, 'kernel': 'rbf', 'C': 1}
# 0.988 (+/-0.005) for {'gamma': 0.001, 'kernel': 'rbf', 'C': 10}
# 0.982 (+/-0.007) for {'gamma': 0.0001, 'kernel': 'rbf', 'C': 10}
# 0.988 (+/-0.005) for {'gamma': 0.001, 'kernel': 'rbf', 'C': 100}
# 0.982 (+/-0.007) for {'gamma': 0.0001, 'kernel': 'rbf', 'C': 100}
# 0.988 (+/-0.005) for {'gamma': 0.001, 'kernel': 'rbf', 'C': 1000}
# 0.982 (+/-0.007) for {'gamma': 0.0001, 'kernel': 'rbf', 'C': 1000}
# 0.974 (+/-0.004) for {'kernel': 'linear', 'C': 1}
# 0.974 (+/-0.004) for {'kernel': 'linear', 'C': 10}
# 0.974 (+/-0.004) for {'kernel': 'linear', 'C': 100}
# 0.974 (+/-0.004) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        89
#           1       0.97      1.00      0.98        90
#           2       0.99      0.98      0.98        92
#           3       1.00      0.99      0.99        93
#           4       1.00      1.00      1.00        76
#           5       0.99      0.98      0.99       108
#           6       0.99      1.00      0.99        89
#           7       0.99      1.00      0.99        78
#           8       1.00      0.98      0.99        92
#           9       0.99      0.99      0.99        92
#
# avg / total       0.99      0.99      0.99       899
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.001,
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)
#
# Grid scores on development set:
#
# 0.986 (+/-0.005) for {'gamma': 0.001, 'kernel': 'rbf', 'C': 1}
# 0.958 (+/-0.007) for {'gamma': 0.0001, 'kernel': 'rbf', 'C': 1}
# 0.987 (+/-0.005) for {'gamma': 0.001, 'kernel': 'rbf', 'C': 10}
# 0.981 (+/-0.007) for {'gamma': 0.0001, 'kernel': 'rbf', 'C': 10}
# 0.987 (+/-0.005) for {'gamma': 0.001, 'kernel': 'rbf', 'C': 100}
# 0.981 (+/-0.007) for {'gamma': 0.0001, 'kernel': 'rbf', 'C': 100}
# 0.987 (+/-0.005) for {'gamma': 0.001, 'kernel': 'rbf', 'C': 1000}
# 0.981 (+/-0.007) for {'gamma': 0.0001, 'kernel': 'rbf', 'C': 1000}
# 0.973 (+/-0.004) for {'kernel': 'linear', 'C': 1}
# 0.973 (+/-0.004) for {'kernel': 'linear', 'C': 10}
# 0.973 (+/-0.004) for {'kernel': 'linear', 'C': 100}
# 0.973 (+/-0.004) for {'kernel': 'linear', 'C': 1000}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        89
#           1       0.97      1.00      0.98        90
#           2       0.99      0.98      0.98        92
#           3       1.00      0.99      0.99        93
#           4       1.00      1.00      1.00        76
#           5       0.99      0.98      0.99       108
#           6       0.99      1.00      0.99        89
#           7       0.99      1.00      0.99        78
#           8       1.00      0.98      0.99        92
#           9       0.99      0.99      0.99        92
#
# avg / total       0.99      0.99      0.99       899
